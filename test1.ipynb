# %%
# Step 1: in your browser type git cli download and install the exe file
# cli - command line

# %%
# Steo 2: open cmd and type git
# Check if command is working or not

# %%
# Create a new repository in github

# %% [markdown]
# ### Git Cheatsheet
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
# Create a README.md file

# %%
# Code to check which github repositories is connected 
# git remote -v

# %%
# To remove the origin (the connecte repository)
# Disconnecting from the repository
# Git remote rm origin

# %%
# in terminal type (git init)

# %%
# In the terminal type this code to add the readme file
# Once you press enter after the code below, you can see the U symbol (untracked) changes to A (Added) and ready to get tracked
# git add README.md

# %%
# To check the list of files added and current status
# git status

# %%
# If you want to remove the added file to untracked
# git rm --cached <file name>

# %%
# to add all the newly created files
# git add .

# %%
# add a new code (## Krish Naik) in the README.md file
# You can notice that the A symbol changes to M
# To push the changes to have to add the code again using (git add <file name>)

# %%
# To link the git cli to my github account
# git config --global user.name "Bishawa"


# To check the user name 
# git config --global user.name

# %%
# Add the email address
# git config --global user.email "bishawasunny4347@gmail.com"


# to check the email id 
# git config --global user.email

# %%
# type (git branch) we will get *master
# we need to change the master branch to main branch
# git branch -M main



# check (git branch)

# %%
# Next code 
# git push origin main
# It will lead you to get the password of your github account



# We can also use the
# git push -u origin main

# %%
# Lets try the code for commit (git commit -m "commit")
# git commit -m "This is my first commit"

# %%
# Create another file app.py 
# Steps to be repeated to add the app.py to github 
# git add app.py
# git status
# git commit -m "Add app.py to github"
# git push origin main
# Refresh the github repository to check if app.py file is added or not

# %% [markdown]
# ### Pull a file from github repository

# %%
# git pull origin main

# %% [markdown]
# ### gitingonre file

# %%
# in github create a new file .gitignore
# choose the template as python

# %%
# now I want to get get the .gitignore file in my system folder
# git pull origin main

# %% [markdown]
# ### cloning a repository in github

# %%
# in the folder location where you want to clone the repository
# open the cmd 
# git clone https://github.com/Bishawa/gitpractice.git

# %% [markdown]
# ### Creating a new branch

# %%
# Type in terminal 
# git branch devloperA

# %%
# to switch to developerA branch
# git checkout developerA

# %%
# write the codes (any code you want to write)
# type in terminal 
# git add .
# git status

# git commit -m "DeveloperA story"

# %%
# I will not do the git push
# now I will merge the code to main branch


# git checkout main     # this will go back to the main branch 
# git branch 


# git merge developerA
